# %%
# %matplotlib notebook
import matplotlib
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 14}
matplotlib.rc('font', **font)

# %% [markdown]
# # Figure 1 - CDFs of Completion Times at Depth=5

# %%
from plot_stats import plot_search_cdf

plot_search_cdf('data/single-core-completions/5-level-single.csv',
                'data/6-22-19/completion_times/5-level-mem.csv',
                'data/6-22-19/completion_times/5-level-ddio.csv',
                'data/6-22-19/completion_times/5-level-reg.csv',
                'data/6-22-19/completion_times/5-level-reg-offload.csv')
# Out:
# Creating plots ...
# <img src="data:image/png;base64,..." width="640">
# 5-level-single Statistics:
# 	99% = 561607.0
# 	50% = 83217.0
# 5-level-mem Statistics:
# 	99% = 44647.36
# 	50% = 40887.0
# 5-level-ddio Statistics:
# 	99% = 42127.26
# 	50% = 38410.5
# 5-level-reg Statistics:
# 	99% = 29900.4
# 	50% = 26824.5
# 5-level-reg-offload Statistics:
# 	99% = 18925.18
# 	50% = 17781.0

# %% [markdown]
# # Figure 2 - Completion Time vs Search Depth

# %%
from plot_stats import plot_completion_stats

plot_completion_stats('data/6-22-19/completion_times/mem-stats-50p.csv',
                      'data/6-22-19/completion_times/ddio-stats-50p.csv',
                      'data/6-22-19/completion_times/reg-stats-50p.csv',
                      'data/6-22-19/completion_times/reg-offload-stats-50p.csv')

plot_completion_stats('data/6-22-19/completion_times/mem-stats-99p.csv',
                      'data/6-22-19/completion_times/ddio-stats-99p.csv',
                      'data/6-22-19/completion_times/reg-stats-99p.csv',
                      'data/6-22-19/completion_times/reg-offload-stats-99p.csv')
# Out:
# Creating plots ...
# <img src="data:image/png;base64,..." width="843">
# Creating plots ...
# <img src="data:image/png;base64,..." width="838">

# %% [markdown]
# # Table 1 - CPU Utilization

# %%
from plot_stats import plot_cpu_util

plot_cpu_util('data/6-22-19/cpu_utilization/branch-5-depth-8/reg-200/cpu-util-reg-200.csv',
              'data/6-22-19/cpu_utilization/branch-5-depth-8/reg-400/cpu-util-reg-400.csv',
              'data/6-22-19/cpu_utilization/branch-5-depth-8/reg-600/cpu-util-reg-600.csv',
              'data/6-22-19/cpu_utilization/branch-5-depth-8/ddio/cpu-util-ddio.csv',
              'data/6-22-19/cpu_utilization/branch-5-depth-8/mem/cpu-util-mem.csv')
# Out:
# Creating plots ...
# <img src="data:image/png;base64,..." width="640">
# cpu-util-reg-200 Statistics:
# 	50% = 0.793216083322
# 	avg = 0.793103310589
# cpu-util-reg-400 Statistics:
# 	50% = 0.783766547159
# 	avg = 0.78401703553
# cpu-util-reg-600 Statistics:
# 	50% = 0.76311036303
# 	avg = 0.763060577762
# cpu-util-ddio Statistics:
# 	50% = 0.715050666388
# 	avg = 0.714600806473
# cpu-util-mem Statistics:
# 	50% = 0.667005970442
# 	avg = 0.667791900754
